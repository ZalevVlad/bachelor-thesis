# %%
import sys
sys.path.append('..')

import help_functions as hf
import matplotlib.pyplot as plt
import numpy as np

folder = "../../segregation/i2/"

# %%
# Нормальное поле
r,z,q = hf.solution_rz_read(folder + "rz")
z = z[1:]
q = q[:,0][1:]
q_a = 1/(2*np.pi*z*1e-2)

fig,ax = plt.subplots(figsize=(5,5))
ax.plot(z,q_a, linewidth = 1, color = 'red')
ax.plot(z,q, "--", color = 'blue')
ax.set_xlim(20,50)
ax.set_ylim(0,2)
plt.show()  

point = hf.low_border(z,10)
print(z[point], q[point],q_a[point], abs(q[point]-q_a[point])/abs(q[point])*100)
# Out:
# [178, 180]
# Q SHAPE:  (180, 178)
# 9.545938177273266 2.322294950628121 1.667253025698485 28.206663617490275

# %%
# Нормальное поле
r,z,q = hf.solution_rz_read(folder + "rz_for_xyz")
rs,re = r.searchsorted(10), r.searchsorted(200)
zs,ze = z.searchsorted(10), z.searchsorted(200)
r = r[rs:re]
z = z[zs:ze]
q = q[zs:ze,rs:re]
hf.paint_layer_uniform(r,z,q,(0,0,0,0),30)
# Out:
# [178, 180]
# Q SHAPE:  (180, 178)

# %%
x,y,z,q = hf.solution_xyz_read(folder+ "xyz1")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
q_a = 1/(2*np.pi*abs(z)*1e-2)
fig,ax = plt.subplots(figsize=(5,5))
# ax.scatter(x,q, marker = 'o', s=10)
# ax.plot(x,q_a, color='red', linewidth = 1)
ax.plot(z,q, color='black', linewidth=3)
ax.set_xlim(50,100)
ax.set_ylim(0,1)

r,z,q = hf.solution_rz_read(folder + "rz_for_xyz")
z = z[1:]
q = q[:,0][1:]
q_a = 1/(2*np.pi*z*1e-2)

ax.plot(z,q, linewidth = 2, color = 'green')
ax.plot(z,q_a, linewidth = 2, color = 'red')
ax.set_xlim(20,80)
ax.set_ylim(0,2)
plt.show()  

point = z.searchsorted(10)
print(z[point],q[point],q_a[point],abs(q[point]-q_a[point])/abs(q[point])*100)
# point2 = x.searchsorted(100)
# print(x[point],x[point2],x[point]/x[point2],q[point]/q[point2],q_a[point]/q_a[point2])
# Out:
# [275, 275, 131]
# Q SHAPE:  (131, 275, 275)
# [178, 180]
# Q SHAPE:  (180, 178)
# C:\Users\zalevskij.2019\AppData\Local\Temp\823\ipykernel_576364\424450768.py:3: RuntimeWarning: divide by zero encountered in divide
#   q_a = 1/(2*np.pi*abs(z)*1e-2)
# 10.501531995000594 1.5119942384014147 1.5155402389638324 0.23452474039628585

# %%
x,y,z,q = hf.solution_xyz_read(folder + "xyz1")
q = q[0,:,:]

xs,xe = x.searchsorted(1), x.searchsorted(20)
ys,ye = y.searchsorted(1), y.searchsorted(20)
zs,ze = z.searchsorted(1), z.searchsorted(20)
x = x[xs:xe]
y = y[ys:ye]
z = z[zs:ze]
q = q[ys:ye,xs:xe]

hf.paint_layer_uniform(x,y,q,(0,0,0,0),20)
# Out:
# [275, 275, 131]
# Q SHAPE:  (131, 275, 275)

# %%
#seg 1
fig,ax = plt.subplots(figsize=(6,6))
ax.set_xlabel('z, м.')
ax.set_ylabel('V')

ax.set_xlim(20,50)
ax.set_ylim(-0.5,2)

x,y,z,q = hf.solution_xyz_read(folder + "xyz1vn")
q = q[1:,y.searchsorted(0),x.searchsorted(0)]
z = z[1:]
ax.plot(z,q,"-s", color='green', linewidth=1)

x,y,z,q = hf.solution_xyz_read(folder + "xyz1va")
z = z[1:]
q = q[1:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"-o", color='black', linewidth=1)

x,y,z,q = hf.solution_xyz_read(folder + "xyz1")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"--o", color='red', linewidth=1)

# q_a = 1/(2*np.pi*z*1e-2)
# ax.plot(z,q_a,"--", color='red', linewidth=1)

r,z,q = hf.solution_rz_read(folder + "rz")
z = z[1:]
q = q[:,0][1:]
ax.plot(z,q,"--", color='red', linewidth=1)


ax.legend(("Vn","Va","V","V*"))
plt.show()  

point = z.searchsorted(10)
print(z[point],q[point],q_a[point],abs(q[point]-q_a[point])/abs(q[point])*100)
# Out:
# [275, 275, 131]
# Q SHAPE:  (131, 275, 275)
# [275, 275, 131]
# Q SHAPE:  (131, 275, 275)
# [275, 275, 131]
# Q SHAPE:  (131, 275, 275)
# [178, 180]
# Q SHAPE:  (180, 178)
# 10.501531995000594 2.174141033647044 1.5155402389638324 30.292459619256263

# %%
#seg 2
fig,ax = plt.subplots(figsize=(6,6))
ax.set_xlabel('z, м.')
ax.set_ylabel('V')

ax.set_xlim(20,50)
ax.set_ylim(-0.5,2)

x,y,z,q = hf.solution_xyz_read(folder + "xyz1vn")
q = q[1:,y.searchsorted(0),x.searchsorted(0)]
z = z[1:]
ax.plot(z,q,"-s", color='green', linewidth=1)

x,y,z,q = hf.solution_xyz_read(folder + "xyz1va")
z = z[1:]
q = q[1:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"-o", color='black', linewidth=1)

x,y,z,q = hf.solution_xyz_read(folder + "xyz1")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"--o", color='red', linewidth=1)

# q_a = 1/(2*np.pi*z*1e-2)
# ax.plot(z,q_a,"--", color='red', linewidth=1)

r,z,q = hf.solution_rz_read(folder + "rz")
z = z[1:]
q = q[:,0][1:]
ax.plot(z,q,"--", color='red', linewidth=1)


ax.legend(("Vn","Va","V","V*"))
plt.show()  

point = z.searchsorted(10)
print(z[point],q[point],q_a[point],abs(q[point]-q_a[point])/abs(q[point])*100)

x,y,z,q = hf.solution_xyz_read(folder + "xyz2vn")
q = q[1:,y.searchsorted(0),x.searchsorted(0)]
z = z[1:]
ax.plot(z,q,"-s", color='green', linewidth=1)

x,y,z,q = hf.solution_xyz_read(folder + "xyz2va")
z = z[1:]
q = q[1:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"-o", color='black', linewidth=1)

x,y,z,q = hf.solution_xyz_read(folder + "xyz2")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"--o", color='red', linewidth=1)

r,z,q = hf.solution_rz_read(folder + "rz")
z = z[1:]
q = q[:,0][1:]
ax.plot(z,q,"--", color='red', linewidth=1)

ax.legend(("Vn","Va","V","V*"))
plt.show()  

point = z.searchsorted(10)
print(z[point],q[point],q_a[point],abs(q[point]-q_a[point])/abs(q[point])*100)
# Out:
# [275, 275, 131]
# Q SHAPE:  (131, 275, 275)
# [275, 275, 131]
# Q SHAPE:  (131, 275, 275)
# [275, 275, 131]
# Q SHAPE:  (131, 275, 275)
# [178, 180]
# Q SHAPE:  (180, 178)
# 10.501531995000594 2.174141033647044 1.5155402389638324 30.292459619256263

# %%
#seg 3
fig,ax = plt.subplots(figsize=(6,6))
ax.set_xlabel('z, м.')
ax.set_ylabel('V')

ax.set_xlim(20,50)
ax.set_ylim(-0.5,2)

x,y,z,q = hf.solution_xyz_read(folder + "xyz1vn")
q = q[1:,y.searchsorted(0),x.searchsorted(0)]
z = z[1:]
ax.plot(z,q,"-s", color='green', linewidth=1)

x,y,z,q = hf.solution_xyz_read(folder + "xyz1va")
z = z[1:]
q = q[1:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"-o", color='black', linewidth=1)

x,y,z,q = hf.solution_xyz_read(folder + "xyz1")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"--o", color='red', linewidth=1)

# q_a = 1/(2*np.pi*z*1e-2)
# ax.plot(z,q_a,"--", color='red', linewidth=1)

r,z,q = hf.solution_rz_read(folder + "rz")
z = z[1:]
q = q[:,0][1:]
ax.plot(z,q,"--", color='red', linewidth=1)


ax.legend(("Vn","Va","V","V*"))
plt.show()  

point = z.searchsorted(10)
print(z[point],q[point],q_a[point],abs(q[point]-q_a[point])/abs(q[point])*100)

x,y,z,q = hf.solution_xyz_read(folder + "xyz3vn")
q = q[1:,y.searchsorted(0),x.searchsorted(0)]
z = z[1:]
ax.plot(z,q,"-s", color='green', linewidth=1)

x,y,z,q = hf.solution_xyz_read(folder + "xyz3va")
# z = z[1:]
# q = q[1:,y.searchsorted(0),x.searchsorted(0)]
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"-o", color='black', linewidth=1)

x,y,z,q = hf.solution_xyz_read(folder + "xyz3")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"--o", color='red', linewidth=1)

r,z,q = hf.solution_rz_read(folder + "rz")
z = z[1:]
q = q[:,0][1:]
ax.plot(z,q,"--", color='red', linewidth=1)

ax.legend(("Vn","Va","V","V*"))
plt.show()  

point = z.searchsorted(10)
print(z[point],q[point],q_a[point],abs(q[point]-q_a[point])/abs(q[point])*100)
# Out:
# [275, 275, 131]
# Q SHAPE:  (131, 275, 275)
# [115, 115, 47]
# Q SHAPE:  (47, 115, 115)
# [275, 275, 131]
# Q SHAPE:  (131, 275, 275)
# [178, 180]
# Q SHAPE:  (180, 178)
# 10.501531995000594 2.174141033647044 1.5155402389638324 30.292459619256263

# %%
#seg 4
fig,ax = plt.subplots(figsize=(6,6))
ax.set_xlabel('z, м.')
ax.set_ylabel('V')

ax.set_xlim(20,50)
ax.set_ylim(-0.5,2)

x,y,z,q = hf.solution_xyz_read(folder + "xyz1vn")
q = q[1:,y.searchsorted(0),x.searchsorted(0)]
z = z[1:]
ax.plot(z,q,"-s", color='green', linewidth=1)

x,y,z,q = hf.solution_xyz_read(folder + "xyz1va")
z = z[1:]
q = q[1:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"-o", color='black', linewidth=1)

x,y,z,q = hf.solution_xyz_read(folder + "xyz1")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"--o", color='red', linewidth=1)

# q_a = 1/(2*np.pi*z*1e-2)
# ax.plot(z,q_a,"--", color='red', linewidth=1)

r,z,q = hf.solution_rz_read(folder + "rz")
z = z[1:]
q = q[:,0][1:]
ax.plot(z,q,"--", color='red', linewidth=1)


ax.legend(("Vn","Va","V","V*"))
plt.show()  

point = z.searchsorted(10)
print(z[point],q[point],q_a[point],abs(q[point]-q_a[point])/abs(q[point])*100)

x,y,z,q = hf.solution_xyz_read(folder + "xyz4vn")
q = q[1:,y.searchsorted(0),x.searchsorted(0)]
z = z[1:]
ax.plot(z,q,"-s", color='green', linewidth=1)

x,y,z,q = hf.solution_xyz_read(folder + "xyz4va")
# z = z[1:]
# q = q[1:,y.searchsorted(0),x.searchsorted(0)]
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"-o", color='black', linewidth=1)

x,y,z,q = hf.solution_xyz_read(folder + "xyz4")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"--o", color='red', linewidth=1)

r,z,q = hf.solution_rz_read(folder + "rz")
z = z[1:]
q = q[:,0][1:]
ax.plot(z,q,"--", color='red', linewidth=1)

ax.legend(("Vn","Va","V","V*"))
plt.show()  

point = z.searchsorted(10)
print(z[point],q[point],q_a[point],abs(q[point]-q_a[point])/abs(q[point])*100)
# Out:
# [275, 275, 131]
# Q SHAPE:  (131, 275, 275)
# [115, 115, 47]
# Q SHAPE:  (47, 115, 115)
# [275, 275, 131]
# Q SHAPE:  (131, 275, 275)
# [178, 180]
# Q SHAPE:  (180, 178)
# 10.501531995000594 2.174141033647044 1.5155402389638324 30.292459619256263

# %%
#seg 5
fig,ax = plt.subplots(figsize=(6,6))
ax.set_xlabel('z, м.')
ax.set_ylabel('V')

ax.set_xlim(0,50)
ax.set_ylim(-5,10)

x,y,z,q = hf.solution_xyz_read(folder + "xyz5vn")
q = q[1:,y.searchsorted(0),x.searchsorted(0)]
z = z[1:]
ax.plot(z,q,"-s", color='green', linewidth=1)

x,y,z,q = hf.solution_xyz_read(folder + "xyz5va")
# z = z[1:]
# q = q[1:,y.searchsorted(0),x.searchsorted(0)]
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"-o", color='black', linewidth=1)

x,y,z,q = hf.solution_xyz_read(folder + "xyz5")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"--o", color='red', linewidth=1)

r,z,q = hf.solution_rz_read(folder + "rz")
z = z[1:]
q = q[:,0][1:]
ax.plot(z,q,"--", color='red', linewidth=1)

ax.legend(("Vn","Va","V","V*"))
plt.show()  

point = z.searchsorted(10)
print(z[point],q[point],q_a[point],abs(q[point]-q_a[point])/abs(q[point])*100)
# Out:
# [275, 275, 131]
# Q SHAPE:  (131, 275, 275)
# [115, 115, 47]
# Q SHAPE:  (47, 115, 115)
# [275, 275, 131]
# Q SHAPE:  (131, 275, 275)
# [178, 180]
# Q SHAPE:  (180, 178)
# 10.501531995000594 2.174141033647044 1.5155402389638324 30.292459619256263

# %%
fig,ax = plt.subplots(figsize=(6,6))
ax.set_xlabel('z, м.')
ax.set_ylabel('V')

ax.set_xlim(20,50)
ax.set_ylim(0,2)

x,y,z,q = hf.solution_xyz_read(folder + "xyz1")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"--o", color='red', linewidth=1,markerfacecolor = 'black')

x,y,z,q = hf.solution_xyz_read(folder + "xyz2")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"--v", color='red', linewidth=1)

x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz3")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"--.", color='green', linewidth=1)

x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz4")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"--x", color='blue', linewidth=1)

x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz5")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"--8", color='black', linewidth=1)

r,z,q = hf.solution_rz_read(folder + "rz")
z = z[1:]
q = q[:,0][1:]
ax.plot(z,q,"-", color='red', linewidth=1)

ax.legend(("V1","V2","V3","V4","V5","V*"))

plt.show()  

point = z.searchsorted(10)
print(z[point],q[point],q_a[point],abs(q[point]-q_a[point])/abs(q[point])*100)
# Out:
# [275, 275, 131]
# Q SHAPE:  (131, 275, 275)
# [275, 275, 131]
# Q SHAPE:  (131, 275, 275)
# [235, 235, 129]
# Q SHAPE:  (129, 235, 235)
# [235, 235, 129]
# Q SHAPE:  (129, 235, 235)
# [235, 235, 129]
# Q SHAPE:  (129, 235, 235)
# [178, 180]
# Q SHAPE:  (180, 178)
# 10.501531995000594 2.174141033647044 1.5155402389638324 30.292459619256263
