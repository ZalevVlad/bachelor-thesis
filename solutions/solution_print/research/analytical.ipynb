# %%
import sys
sys.path.append('..')

import help_functions as hf
import matplotlib.pyplot as plt
import numpy as np

# %%
# Нормальное поле
r,z,q = hf.solution_rz_read("../../segregation/analytical/rz_for_xyz")
z = z[1:]
q = q[:,0][1:]
# hf.paint_layer_uniform(r,z,q,(0,0,0,0),0)
q_a = 1/(2*np.pi*z*1e-2)

fig,ax = plt.subplots(figsize=(6,6))
# ax.scatter(r,q, marker = 'o', s=10)
ax.plot(z,q_a, linewidth = 1, color = 'red')
ax.plot(z,q, "--", color = 'blue')
ax.set_xlim(5,25)
ax.set_ylim(0,10)
plt.show()  

# fig,ax = plt.subplots(figsize=(6,6))
# ax.plot(r,q[0],color='green')
# ax.plot(r,r_a, color='red')
# ax.set_xlim(0,10)
# ax.set_ylim(0,10)
# plt.show()

fig,ax = plt.subplots(figsize=(6,6))
ax.plot(z,abs(q-q_a)/abs(q)*100,color='blue')
ax.set_xlim(0,1000)
ax.set_ylim(0,100)
plt.show()

point = hf.low_border(z,10)
print(z[point], q[point],q_a[point], abs(q[point]-q_a[point])/abs(q[point])*100)
# Out:
# [178, 180]
# Q SHAPE:  (180, 178)
# C:\Users\zalevskij.2019\AppData\Local\Temp\819\ipykernel_190956\3456097830.py:24: RuntimeWarning: divide by zero encountered in divide
#   ax.plot(z,abs(q-q_a)/abs(q)*100,color='blue')
# 9.545938177273266 4.871386990533807 1.667253025698485 65.77457243823311

# %%
# Нормальное поле
r,z,q = hf.solution_rz_read("../../segregation/analytical/rz_for_xyz")
rs,re = r.searchsorted(10), r.searchsorted(200)
zs,ze = z.searchsorted(10), z.searchsorted(200)
r = r[rs:re]
z = z[zs:ze]
q = q[zs:ze,rs:re]
hf.paint_layer_uniform(r,z,q,(0,0,0,0),5)
# Out:
# [178, 180]
# Q SHAPE:  (180, 178)

# %%
x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz3")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
q_a = 1/(2*np.pi*abs(z)*1e-2)
fig,ax = plt.subplots(figsize=(6,6))
# ax.scatter(x,q, marker = 'o', s=10)
# ax.plot(x,q_a, color='red', linewidth = 1)
ax.plot(z,q, color='black', linewidth=3)
ax.set_xlim(50,100)
ax.set_ylim(0,1)

r,z,q = hf.solution_rz_read("../../segregation/analytical/rz_for_xyz")
z = z[1:]
q = q[:,0][1:]
q_a = 1/(2*np.pi*z*1e-2)

ax.plot(z,q, linewidth = 2, color = 'green')
ax.plot(z,q_a, linewidth = 2, color = 'red')
ax.set_xlim(5,25)
ax.set_ylim(0,10)
plt.show()  

point = z.searchsorted(10)
print(z[point],q[point],q_a[point],abs(q[point]-q_a[point])/abs(q[point])*100)
# point2 = x.searchsorted(100)
# print(x[point],x[point2],x[point]/x[point2],q[point]/q[point2],q_a[point]/q_a[point2])
# Out:
# [193, 193, 108]
# Q SHAPE:  (108, 193, 193)
# [178, 180]
# Q SHAPE:  (180, 178)
# C:\Users\zalevskij.2019\AppData\Local\Temp\819\ipykernel_190956\3465875158.py:3: RuntimeWarning: divide by zero encountered in divide
#   q_a = 1/(2*np.pi*abs(z)*1e-2)
# 10.0 4.861803970693385 1.5915494309189535 67.2642204310848

# %%
x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz1")
q = q[0,:,:]

xs,xe = x.searchsorted(1), x.searchsorted(20)
ys,ye = y.searchsorted(1), y.searchsorted(20)
zs,ze = z.searchsorted(1), z.searchsorted(20)
x = x[xs:xe]
y = y[ys:ye]
z = z[zs:ze]
q = q[ys:ye,xs:xe]

hf.paint_layer_uniform(x,y,q,(0,0,0,0),20)
# Out:
# [193, 193, 108]
# Q SHAPE:  (108, 193, 193)

# %%
#segregation 1
fig,ax = plt.subplots(figsize=(6,6))
ax.set_xlabel('z, м.')
ax.set_ylabel('V')

ax.set_xlim(1,25)
ax.set_ylim(-4,6)

x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz1vn")
q = q[1:,y.searchsorted(0),x.searchsorted(0)]
z = z[1:]
ax.plot(z,q,"-s", color='green', linewidth=1)

x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz1va")
z = z[1:]
q = q[1:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"-o", color='black', linewidth=1)

x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz1")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"--o", color='red', linewidth=1)

q_a = 1/(2*np.pi*z*1e-2)
ax.plot(z,q_a,"--", color='red', linewidth=1)

ax.legend(("Vn","Va","V","V*"))
plt.show()  

point = z.searchsorted(10)
print(z[point],q[point],q_a[point],abs(q[point]-q_a[point])/abs(q[point])*100)
# Out:
# [193, 193, 108]
# Q SHAPE:  (108, 193, 193)
# [193, 193, 108]
# Q SHAPE:  (108, 193, 193)
# [193, 193, 108]
# Q SHAPE:  (108, 193, 193)
# C:\Users\zalevskij.2019\AppData\Local\Temp\819\ipykernel_190956\2941704946.py:23: RuntimeWarning: divide by zero encountered in divide
#   q_a = 1/(2*np.pi*z*1e-2)
# 10.0 1.8414119409767205 1.5915494309189535 13.569071889760584

# %%
#segregation 2
fig,ax = plt.subplots(figsize=(6,6))
ax.set_xlabel('z, м.')
ax.set_ylabel('V')

ax.set_xlim(1,25)
ax.set_ylim(-4,6)

x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz2vn")
q = q[1:,y.searchsorted(0),x.searchsorted(0)]
z = z[1:]
ax.plot(z,q,"-s", color='green', linewidth=1)

x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz2va")
z = z[1:]
q = q[1:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"-o", color='black', linewidth=1)

x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz2")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"--o", color='red', linewidth=1)

q_a = 1/(2*np.pi*z*1e-2)
ax.plot(z,q_a,"--", color='red', linewidth=1)

ax.legend(("Vn","Va","V","V*"))
plt.show()  

point = z.searchsorted(10)
print(z[point],q[point],q_a[point],abs(q[point]-q_a[point])/abs(q[point])*100)
# Out:
# [193, 193, 108]
# Q SHAPE:  (108, 193, 193)
# [193, 193, 108]
# Q SHAPE:  (108, 193, 193)
# [193, 193, 108]
# Q SHAPE:  (108, 193, 193)
# C:\Users\zalevskij.2019\AppData\Local\Temp\819\ipykernel_190956\1538335644.py:23: RuntimeWarning: divide by zero encountered in divide
#   q_a = 1/(2*np.pi*z*1e-2)
# 10.0 1.5723903716339205 1.5915494309189535 1.2184670951097372

# %%
#segregation 3
fig,ax = plt.subplots(figsize=(6,6))
ax.set_xlabel('z, м.')
ax.set_ylabel('V')

ax.set_xlim(1,25)
ax.set_ylim(-4,6)

x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz3vn")
q = q[1:,y.searchsorted(0),x.searchsorted(0)]
z = z[1:]
ax.plot(z,q,"-s", color='green', linewidth=1)

x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz3va")
# z = z[1:]
# q = q[1:,y.searchsorted(0),x.searchsorted(0)]
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"-o", color='black', linewidth=1)

x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz3")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"--o", color='red', linewidth=1)

q_a = 1/(2*np.pi*z*1e-2)
ax.plot(z,q_a,"--", color='red', linewidth=1)

ax.legend(("Vn","Va","V","V*"))
plt.show()  

point = z.searchsorted(5)
print(z[point],q[point],q_a[point],abs(q[point]-q_a[point])/abs(q[point])*100)
# Out:
# [193, 193, 108]
# Q SHAPE:  (108, 193, 193)
# [33, 33, 24]
# Q SHAPE:  (24, 33, 33)
# [193, 193, 108]
# Q SHAPE:  (108, 193, 193)
# C:\Users\zalevskij.2019\AppData\Local\Temp\819\ipykernel_190956\1785381876.py:24: RuntimeWarning: divide by zero encountered in divide
#   q_a = 1/(2*np.pi*z*1e-2)
# 5.098373499892655 3.1174522387424197 3.1216807300455 0.13563932914610147

# %%
#segregation 4
fig,ax = plt.subplots(figsize=(6,6))
ax.set_xlabel('z, м.')
ax.set_ylabel('V')

ax.set_xlim(1,25)
ax.set_ylim(-4,6)

x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz4vn")
q = q[1:,y.searchsorted(0),x.searchsorted(0)]
z = z[1:]
ax.plot(z,q,"-s", color='green', linewidth=1)

x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz4va")
# z = z[1:]
# q = q[1:,y.searchsorted(0),x.searchsorted(0)]
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"-o", color='black', linewidth=1)

x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz4")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"--o", color='red', linewidth=1)

q_a = 1/(2*np.pi*z*1e-2)
ax.plot(z,q_a,"--", color='red', linewidth=1)

ax.legend(("Vn","Va","V","V*"))
plt.show()  

point = z.searchsorted(5)
print(z[point],q[point],q_a[point],abs(q[point]-q_a[point])/abs(q[point])*100)
# Out:
# [193, 193, 108]
# Q SHAPE:  (108, 193, 193)
# [33, 33, 24]
# Q SHAPE:  (24, 33, 33)
# [193, 193, 108]
# Q SHAPE:  (108, 193, 193)
# C:\Users\zalevskij.2019\AppData\Local\Temp\819\ipykernel_190956\959085810.py:24: RuntimeWarning: divide by zero encountered in divide
#   q_a = 1/(2*np.pi*z*1e-2)
# 5.098373499892655 3.2280464059357574 3.1216807300455 3.295047917981331

# %%
#segregation5
fig,ax = plt.subplots(figsize=(6,6))
ax.set_xlabel('z, м.')
ax.set_ylabel('V')

ax.set_xlim(1,25)
ax.set_ylim(-4,6)

x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz5vn")
q = q[1:,y.searchsorted(0),x.searchsorted(0)]
z = z[1:]
ax.plot(z,q,"-s", color='green', linewidth=1)

x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz5va")
# z = z[1:]
# q = q[1:,y.searchsorted(0),x.searchsorted(0)]
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"-o", color='black', linewidth=1)

x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz5")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"--o", color='red', linewidth=1)

q_a = 1/(2*np.pi*z*1e-2)
ax.plot(z,q_a,"--", color='red', linewidth=1)

ax.legend(("Vn","Va","V","V*"))
plt.show()  

point = z.searchsorted(5)
print(z[point],q[point],q_a[point],abs(q[point]-q_a[point])/abs(q[point])*100)
# Out:
# [193, 193, 108]
# Q SHAPE:  (108, 193, 193)
# [33, 33, 24]
# Q SHAPE:  (24, 33, 33)
# [193, 193, 108]
# Q SHAPE:  (108, 193, 193)
# C:\Users\zalevskij.2019\AppData\Local\Temp\819\ipykernel_190956\618721454.py:24: RuntimeWarning: divide by zero encountered in divide
#   q_a = 1/(2*np.pi*z*1e-2)
# 5.098373499892655 2.859028406639247 3.1216807300455 9.186768581813345

# %%
fig,ax = plt.subplots(figsize=(6,6))
ax.set_xlabel('z, м.')
ax.set_ylabel('V')

ax.set_xlim(5,25)
ax.set_ylim(0,3)


x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz1")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"--o", color='red', linewidth=1,markerfacecolor = 'black')

il = hf.low_border(z,3)
ih = hf.low_border(z,25)
q_a = 1/(2*np.pi*z*1e-2)
print(f"V1 otn pogr = {np.linalg.norm(abs((q[il:ih]-q_a[il:ih])/q[il:ih]))*100:e}%")

x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz2")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"--v", color='red', linewidth=1)
print(f"V2 otn pogr = {np.linalg.norm(abs((q[il:ih]-q_a[il:ih])/q[il:ih]))*100:e}%")

x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz3")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"--.", color='green', linewidth=1)
print(f"V3 otn pogr = {np.linalg.norm(abs((q[il:ih]-q_a[il:ih])/q[il:ih]))*100:e}%")

x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz4")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"--x", color='blue', linewidth=1)
print(f"V4 otn pogr = {np.linalg.norm(abs((q[il:ih]-q_a[il:ih])/q[il:ih]))*100:e}%")

x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz5")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"--8", color='black', linewidth=1)
print(f"V5 otn pogr = {np.linalg.norm(abs((q[il:ih]-q_a[il:ih])/q[il:ih]))*100:e}%")

ax.plot(z,q_a,"-", color='red', linewidth=1)


ax.legend(("V1","V2","V3","V4","V5","V*"))
plt.show()  

point = z.searchsorted(10)
print(z[point],q[point],q_a[point],abs(q[point]-q_a[point])/abs(q[point])*100)
# Out:
# [193, 193, 108]
# Q SHAPE:  (108, 193, 193)
# V1 otn pogr = 6.558534e+01%
# [193, 193, 108]
# C:\Users\zalevskij.2019\AppData\Local\Temp\819\ipykernel_190956\4163211888.py:15: RuntimeWarning: divide by zero encountered in divide
#   q_a = 1/(2*np.pi*z*1e-2)
# Q SHAPE:  (108, 193, 193)
# V2 otn pogr = 6.867171e+00%
# [193, 193, 108]
# Q SHAPE:  (108, 193, 193)
# V3 otn pogr = 3.278925e+00%
# [193, 193, 108]
# Q SHAPE:  (108, 193, 193)
# V4 otn pogr = 1.915450e+01%
# [193, 193, 108]
# Q SHAPE:  (108, 193, 193)
# V5 otn pogr = 5.468346e+01%
# 10.0 1.3625686781149633 1.5915494309189535 16.805079735193395

# %%
fig,ax = plt.subplots(figsize=(6,6))
ax.set_xlabel('z, м.')
ax.set_ylabel('V')

ax.set_xlim(20,50)
ax.set_ylim(0.3,0.6)


x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz1")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"--o", color='red', linewidth=1,markerfacecolor = 'black')

il = hf.low_border(z,3)
ih = hf.low_border(z,25)
q_a = 1/(2*np.pi*z*1e-2)
print(f"V1 otn pogr = {np.linalg.norm(abs((q[il:ih]-q_a[il:ih])/q[il:ih]))*100:e}%")

x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz2")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"--v", color='red', linewidth=1)
print(f"V2 otn pogr = {np.linalg.norm(abs((q[il:ih]-q_a[il:ih])/q[il:ih]))*100:e}%")

x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz3")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"--.", color='green', linewidth=1)
print(f"V3 otn pogr = {np.linalg.norm(abs((q[il:ih]-q_a[il:ih])/q[il:ih]))*100:e}%")

x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz4")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"--x", color='blue', linewidth=1)
print(f"V4 otn pogr = {np.linalg.norm(abs((q[il:ih]-q_a[il:ih])/q[il:ih]))*100:e}%")

x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz5")
q = q[:,y.searchsorted(0),x.searchsorted(0)]
ax.plot(z,q,"--8", color='black', linewidth=1)
print(f"V5 otn pogr = {np.linalg.norm(abs((q[il:ih]-q_a[il:ih])/q[il:ih]))*100:e}%")

ax.plot(z,q_a,"-", color='red', linewidth=1)


ax.legend(("V1","V2","V3","V4","V5","V*"))
plt.show()  

point = z.searchsorted(10)
print(z[point],q[point],q_a[point],abs(q[point]-q_a[point])/abs(q[point])*100)
# Out:
# [193, 193, 108]
# Q SHAPE:  (108, 193, 193)
# V1 otn pogr = 6.558534e+01%
# [193, 193, 108]
# C:\Users\zalevskij.2019\AppData\Local\Temp\819\ipykernel_190956\720133433.py:15: RuntimeWarning: divide by zero encountered in divide
#   q_a = 1/(2*np.pi*z*1e-2)
# Q SHAPE:  (108, 193, 193)
# V2 otn pogr = 6.867171e+00%
# [193, 193, 108]
# Q SHAPE:  (108, 193, 193)
# V3 otn pogr = 3.278925e+00%
# [193, 193, 108]
# Q SHAPE:  (108, 193, 193)
# V4 otn pogr = 1.915450e+01%
# [193, 193, 108]
# Q SHAPE:  (108, 193, 193)
# V5 otn pogr = 5.468346e+01%
# 10.0 1.3625686781149633 1.5915494309189535 16.805079735193395

# %%
fig,ax = plt.subplots(figsize=(6,6))
ax.set_xlabel('x, м.')
ax.set_ylabel('N, %')

ax.set_xlim(0,100)
ax.set_ylim(0,100)


x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz1")
q = q[0,y.searchsorted(0),:]
q_a = 1/(2*np.pi*x*1e-2)
ax.plot(x,abs(q-q_a)/abs(q)*100,"--o", color='red', linewidth=1,markerfacecolor = 'black')

# il = hf.low_border(z,3)
# ih = hf.low_border(z,25)
# print(f"V1 otn pogr = {np.linalg.norm(abs((q[il:ih]-q_a[il:ih])/q[il:ih]))*100:e}%")

# x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz2")
# q = q[:,y.searchsorted(0),x.searchsorted(0)]
# ax.plot(z,q,"--v", color='red', linewidth=1)
# print(f"V2 otn pogr = {np.linalg.norm(abs((q[il:ih]-q_a[il:ih])/q[il:ih]))*100:e}%")

# x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz3")
# q = q[:,y.searchsorted(0),x.searchsorted(0)]
# ax.plot(z,q,"--.", color='green', linewidth=1)
# print(f"V3 otn pogr = {np.linalg.norm(abs((q[il:ih]-q_a[il:ih])/q[il:ih]))*100:e}%")

# x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz4")
# q = q[:,y.searchsorted(0),x.searchsorted(0)]
# ax.plot(z,q,"--x", color='blue', linewidth=1)
# print(f"V4 otn pogr = {np.linalg.norm(abs((q[il:ih]-q_a[il:ih])/q[il:ih]))*100:e}%")

# x,y,z,q = hf.solution_xyz_read("../../segregation/analytical/xyz5")
# q = q[:,y.searchsorted(0),x.searchsorted(0)]
# ax.plot(z,q,"--8", color='black', linewidth=1)
# print(f"V5 otn pogr = {np.linalg.norm(abs((q[il:ih]-q_a[il:ih])/q[il:ih]))*100:e}%")

# ax.plot(z,q_a,"-", color='red', linewidth=1)


ax.legend(("V1","V2","V3","V4","V5","V*"))
plt.show()  

point = z.searchsorted(10)
print(z[point],q[point],q_a[point],abs(q[point]-q_a[point])/abs(q[point])*100)
# Out:
# [193, 193, 108]
# Q SHAPE:  (108, 193, 193)
# C:\Users\zalevskij.2019\AppData\Local\Temp\819\ipykernel_190956\2050127534.py:11: RuntimeWarning: divide by zero encountered in divide
#   q_a = 1/(2*np.pi*x*1e-2)
# 10.0 0.4760021811051054 -0.5037546206167224 205.83031771980242
